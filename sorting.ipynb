# %%
import pandas as pd

# %%
df=pd.read_csv('/Reactions.csv')
df.head()
# Out:
#    Unnamed: 0                            Content ID        Type  \
# 0           1  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 1           2  97522e57-d9ab-4bd6-97bf-c24d952602d2     dislike
# 2           3  97522e57-d9ab-4bd6-97bf-c24d952602d2      scared
# 3           4  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 4           5  97522e57-d9ab-4bd6-97bf-c24d952602d2  interested
#
#            Datetime Content Type  Category Sentiment  Score  Unnamed: 8  \
# 0  07-11-2020 09:43        photo  Studying  negative    0.0         NaN
# 1  17-06-2021 12:22        photo  Studying  negative   10.0         NaN
# 2  18-04-2021 05:13        photo  Studying  negative   15.0         NaN
# 3  06-01-2021 19:13        photo  Studying  negative    0.0         NaN
# 4  23-08-2020 12:25        photo  Studying  positive   30.0         NaN
#
#    Unnamed: 9
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24573 entries, 0 to 24572
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    24573 non-null  int64
#  1   Content ID    24573 non-null  object
#  2   Type          24573 non-null  object
#  3   Datetime      24573 non-null  object
#  4   Content Type  24573 non-null  object
#  5   Category      24573 non-null  object
#  6   Sentiment     24573 non-null  object
#  7   Score         24573 non-null  float64
#  8   Unnamed: 8    0 non-null      float64
#  9   Unnamed: 9    0 non-null      float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 1.9+ MB

# %%
df2=df.groupby('Category')['Score'].sum()

# %%
df2
# Out:
# Category
# Animals             3723.0
# Culture             1627.0
# Education           1395.0
# Fitness             5488.0
# Food                3504.0
# Healthy Eating       272.0
# Public Speaking     1336.0
# Science             4619.0
# Soccer              2631.0
# Studying            1341.0
# Technology           217.0
# Travel              1092.0
# Veganism             644.0
# animals            71242.0
# cooking            64756.0
# culture            64952.0
# dogs               52511.0
# education          56041.0
# fitness            49835.0
# food               63172.0
# healthy eating     69067.0
# public speaking    47928.0
# science            66549.0
# soccer             55152.0
# studying           52928.0
# technology         68521.0
# tennis             50339.0
# travel             63788.0
# veganism           48975.0
# Name: Score, dtype: float64

# %%
sorted_series = df2.sort_values()

# %%
sorted_series.tail(5)
# Out:
# Category
# culture           64952.0
# science           66549.0
# technology        68521.0
# healthy eating    69067.0
# animals           71242.0
# Name: Score, dtype: float64
